# %%
import pandas as pd
import numpy as np
import os
import Manuel as mn

# %%
df = mn.cargar_dataset('Cambridge.csv')
df.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8521   https://www.airbnb.com/rooms/8521  20241228025327   2024-12-28
# 1  11169  https://www.airbnb.com/rooms/11169  20241228025327   2024-12-28
# 2  19581  https://www.airbnb.com/rooms/19581  20241228025327   2024-12-28
# 3  27498  https://www.airbnb.com/rooms/27498  20241228025327   2024-12-28
# 4  79762  https://www.airbnb.com/rooms/79762  20241228025327   2024-12-28
#
#             source                                              name  \
# 0  previous scrape  SunsplashedSerenity walk to Harvard & Fresh Pond
# 1  previous scrape     Lovely Studio Room: Available for long w/ends
# 2      city scrape                          Furnished suite, Windsor
# 3      city scrape                   Furnished suite 2 @ the Windsor
# 4      city scrape                 Cambridge Getaway @ Harvard & MIT
#
#                                          description  \
# ...

# %%
reem_nul = mn.reemplazar_nulos(df)
reem_nul
# Out:
# /Users/josemanuelfloresperez/Desktop/N Carga de datos/Reposición_1/Manuel.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(1000001, inplace=True)
# /Users/josemanuelfloresperez/Desktop/N Carga de datos/Reposición_1/Manuel.py:39: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
cuenta_de_nulos = mn.cuenta_nulos(reem_nul)
cuenta_de_nulos
# Out:
# ('Valores nulos por columna',
#  id                                              0
#  listing_url                                     0
#  scrape_id                                       0
#  last_scraped                                    0
#  source                                          0
#                                                 ..
#  calculated_host_listings_count                  0
#  calculated_host_listings_count_entire_homes     0
#  calculated_host_listings_count_private_rooms    0
#  calculated_host_listings_count_shared_rooms     0
#  reviews_per_month                               0
#  Length: 75, dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(0))

# %%
datos_limpios = mn.limpiar_atipicos(reem_nul)
datos_limpios
# Out:
#                        id                                       listing_url  \
# 0                    8521                 https://www.airbnb.com/rooms/8521
# 1                   11169                https://www.airbnb.com/rooms/11169
# 2                   19581                https://www.airbnb.com/rooms/19581
# 3                   27498                https://www.airbnb.com/rooms/27498
# 4                   79762                https://www.airbnb.com/rooms/79762
# ...                   ...                                               ...
# 1282  1313250609203710870  https://www.airbnb.com/rooms/1313250609203710870
# 1283  1313277221998634744  https://www.airbnb.com/rooms/1313277221998634744
# 1284  1313301960513049198  https://www.airbnb.com/rooms/1313301960513049198
# 1285  1314036192803424107  https://www.airbnb.com/rooms/1314036192803424107
# 1286  1316146649117544288  https://www.airbnb.com/rooms/1316146649117544288
#
#            scrape_id last_scraped           source  \
# ...

# %%
cuenta_val_nul = mn.cuenta_nulos(datos_limpios)
cuenta_val_nul
# Out:
# ('Valores nulos por columna',
#  id                                              0
#  listing_url                                     0
#  scrape_id                                       0
#  last_scraped                                    0
#  source                                          0
#                                                 ..
#  calculated_host_listings_count                  0
#  calculated_host_listings_count_entire_homes     0
#  calculated_host_listings_count_private_rooms    0
#  calculated_host_listings_count_shared_rooms     0
#  reviews_per_month                               0
#  Length: 75, dtype: int64,
#  'Valores nulos por dataframe',
#  np.int64(0))

# %%
datos_limpios.to_csv("Cambridge_limpio.csv")
